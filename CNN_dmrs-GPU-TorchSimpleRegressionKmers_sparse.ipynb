# %%
# Train a CNN regression to predict the mCG level of all DMRs
import pandas as pd
import csv
import numpy as np
import time
import matplotlib.pyplot as plt
import seqlogo
from IPython.display import clear_output
import datetime
from scipy.stats import spearmanr
import csv
from scipy import sparse

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

torch.cuda.is_available()
# Out:
# False

# %%
# Load DMR mCG levels
dmrs_mc = pd.read_csv('/cndd/emukamel/CNN_DMR/data_INTACT/Mouse_DMRs_methylation_level.csv',
                  names=['Clust%d' % i for i in range(15)], header=None, index_col=False)
dmrs_mc = torch.tensor(dmrs_mc.to_numpy(), dtype=torch.float)

ndmrs, ncelltypes = dmrs_mc.shape
print(ndmrs, ncelltypes)
# Out:
# 58959 15

# %%
dmrs_mcu = dmrs_mc.numpy()
dmrs_mc_mean = dmrs_mc.mean(axis=1)
# plt.plot(np.mean(dmrs_mcu,axis=1), np.std(dmrs_mcu,axis=1),'.')
# dmrs_mcu[0:5,:]
np.mean(dmrs_mcu,axis=1).shape
dmrs_mc_mean.shape
# Out:
# torch.Size([58959])

# %%
# # Load Kmers
# K = 8;
# fn_kmer = '/cndd/emukamel/snmCSeq/DMR/Kmer_Features/Kmers_K'+str(K)+'_counts.csv'
# kmers = pd.read_csv(fn_kmer, header=None)
# nkmers = kmers.shape[1]
# kmers = torch.tensor(kmers.to_numpy(), dtype=torch.int)
# print(kmers.shape)

# %%
# K = 8;
# fn_kmer = '/cndd/emukamel/snmCSeq/DMR/Kmer_Features/Kmers_K'+str(K)+'_counts.csv'
# reader = csv.reader(open(fn_kmer, 'rt'))

# chunk, chunksize = [], 100

# def process_chunk(chuck):
#     print('hi: %d' % len(chuck))
#     return sparse.csr_matrix(np.array(chunk,dtype=int))

# kmer = sparse.csr_matrix([],dtype=int)
# t0 = time.time()
# for i, line in enumerate(reader):
#     if (i % chunksize == 0 and i > 0):
#         schunk = sparse.csr_matrix(np.array(chunk,dtype=int))
#         if kmer.nnz<1:
#             kmer = schunk;
#         else:
#             kmer = sparse.vstack([kmer,schunk], format='csr', dtype=int)
#         if (time.time()-t0 > 5):
#             print('i=%d, t=%3.3g ' % (i, time.time()-t0))
#             t0 = time.time()
#         chunk = []
#     chunk.append(line)

# # process the remainder
# schunk = sparse.csr_matrix(np.array(chunk,dtype=int))
# kmer = sparse.vstack([kmer,schunk], format='csr', dtype=int)
# sparse.save_npz(fn_kmer.strip('.csv')+'.npz', kmer)
# Out:
# i=200, t=0.853
# i=300, t=1.23
# i=400, t=1.61
# i=500, t=1.98
# i=600, t=2.36
# i=700, t=2.73
# i=800, t=3.1
# i=900, t=3.48
# i=1000, t=3.85
# i=1100, t=4.22
# i=1200, t=4.6
# i=1300, t=4.98
# i=1400, t=5.35
# i=1500, t=5.73
# i=1600, t=6.11
# i=1700, t=6.48
# i=1800, t=6.86
# i=1900, t=7.25
# i=2000, t=7.63
# i=2100, t=8.01
# i=2200, t=8.39
# i=2300, t=8.76
# i=2400, t=9.14
# i=2500, t=9.52
# i=2600, t=9.91
# i=2700, t=10.3
# i=2800, t=10.7
# i=2900, t=11.1
# i=3000, t=11.4
# i=3100, t=11.8
# i=3200, t=12.2
# i=3300, t=12.6
# i=3400, t= 13
# i=3500, t=13.3
# i=3600, t=13.7
# i=3700, t=14.1
# i=3800, t=14.5
# i=3900, t=14.9
# i=4000, t=15.2
# i=4100, t=15.6
# i=4200, t= 16
# i=4300, t=16.4
# i=4400, t=16.8
# i=4500, t=17.2
# i=4600, t=17.6
# i=4700, t=18.1
# i=4800, t=18.5
# i=4900, t=18.9
# i=5000, t=19.3
# i=5100, t=19.7
# i=5200, t=20.1
# i=5300, t=20.5
# i=5400, t=20.9
# i=5500, t=21.3
# i=5600, t=21.7
# i=5700, t=22.1
# i=5800, t=22.6
# i=5900, t= 23
# i=6000, t=23.4
# i=6100, t=23.8
# i=6200, t=24.2
# i=6300, t=24.6
# i=6400, t=25.1
# i=6500, t=25.5
# i=6600, t=25.9
# i=6700, t=26.3
# i=6800, t=26.7
# i=6900, t=27.1
# i=7000, t=27.6
# i=7100, t= 28
# i=7200, t=28.4
# i=7300, t=28.8
# i=7400, t=29.3
# i=7500, t=29.7
# i=7600, t=30.1
# i=7700, t=30.5
# i=7800, t=30.9
# i=7900, t=31.4
# i=8000, t=31.8
# i=8100, t=32.2
# i=8200, t=32.6
# i=8300, t= 33
# i=8400, t=33.4
# i=8500, t=33.8
# i=8600, t=34.2
# i=8700, t=34.6
# i=8800, t= 35
# i=8900, t=35.4
# i=9000, t=35.9
# i=9100, t=36.3
# i=9200, t=36.7
# i=9300, t=37.1
# i=9400, t=37.6
# i=9500, t= 38
# i=9600, t=38.5
# i=9700, t= 39
# i=9800, t=39.4
# i=9900, t=39.9
# i=10000, t=40.4
# i=10100, t=40.8
# i=10200, t=41.3
# i=10300, t=41.8
# i=10400, t=42.2
# i=10500, t=42.7
# i=10600, t=43.2
# i=10700, t=43.7
# i=10800, t=44.1
# i=10900, t=44.6
# i=11000, t=45.1
# i=11100, t=45.6
# i=11200, t= 46
# i=11300, t=46.5
# i=11400, t= 47
# i=11500, t=47.5
# i=11600, t= 48
# i=11700, t=48.4
# i=11800, t=48.9
# i=11900, t=49.4
# i=12000, t=49.9
# i=12100, t=50.4
# i=12200, t=50.9
# i=12300, t=51.3
# i=12400, t=51.8
# i=12500, t=52.3
# i=12600, t=52.8
# i=12700, t=53.3
# i=12800, t=53.8
# i=12900, t=54.3
# i=13000, t=54.8
# i=13100, t=55.3
# i=13200, t=55.8
# i=13300, t=56.3
# i=13400, t=56.8
# i=13500, t=57.3
# i=13600, t=57.8
# i=13700, t=58.3
# i=13800, t=58.8
# i=13900, t=59.3
# i=14000, t=59.8
# i=14100, t=60.3
# i=14200, t=60.8
# i=14300, t=61.3
# i=14400, t=61.8
# i=14500, t=62.3
# i=14600, t=62.8
# i=14700, t=63.3
# i=14800, t=63.8
# i=14900, t=64.4
# i=15000, t=64.9
# i=15100, t=65.4
# i=15200, t=65.9
# i=15300, t=66.4
# i=15400, t=66.9
# i=15500, t=67.4
# i=15600, t= 68
# i=15700, t=68.5
# i=15800, t= 69
# i=15900, t=69.5
# i=16000, t= 70
# i=16100, t=70.6
# i=16200, t=71.1
# i=16300, t=71.6
# i=16400, t=72.1
# i=16500, t=72.6
# i=16600, t=73.2
# i=16700, t=73.7
# i=16800, t=74.2
# i=16900, t=74.8
# i=17000, t=75.3
# i=17100, t=75.8
# i=17200, t=76.4
# i=17300, t=76.9
# i=17400, t=77.4
# i=17500, t= 78
# i=17600, t=78.5
# i=17700, t= 79
# i=17800, t=79.6
# i=17900, t=80.1
# i=18000, t=80.7
# i=18100, t=81.2
# i=18200, t=81.7
# i=18300, t=82.3
# i=18400, t=82.8
# i=18500, t=83.4
# i=18600, t=83.9
# i=18700, t=84.5
# i=18800, t= 85
# i=18900, t=85.6
# i=19000, t=86.1
# i=19100, t=86.6
# i=19200, t=87.2
# i=19300, t=87.8
# i=19400, t=88.3
# i=19500, t=88.9
# i=19600, t=89.4
# i=19700, t= 90
# i=19800, t=90.5
# i=19900, t=91.1
# i=20000, t=91.6
# i=20100, t=92.2
# i=20200, t=92.8
# i=20300, t=93.3
# i=20400, t=93.9
# i=20500, t=94.5
# i=20600, t= 95
# i=20700, t=95.6
# i=20800, t=96.2
# i=20900, t=96.7
# i=21000, t=97.3
# i=21100, t=97.9
# i=21200, t=98.5
# i=21300, t= 99
# i=21400, t=99.6
# i=21500, t=100
# i=21600, t=101
# i=21700, t=101
# i=21800, t=102
# i=21900, t=102
# i=22000, t=103
# i=22100, t=104
# i=22200, t=104
# i=22300, t=105
# i=22400, t=105
# i=22500, t=106
# i=22600, t=107
# i=22700, t=107
# i=22800, t=108
# i=22900, t=108
# i=23000, t=109
# i=23100, t=109
# i=23200, t=110
# i=23300, t=111
# i=23400, t=111
# i=23500, t=112
# i=23600, t=112
# i=23700, t=113
# i=23800, t=114
# i=23900, t=114
# i=24000, t=115
# i=24100, t=115
# i=24200, t=116
# i=24300, t=117
# i=24400, t=117
# i=24500, t=118
# i=24600, t=118
# i=24700, t=119
# i=24800, t=120
# i=24900, t=120
# i=25000, t=121
# i=25100, t=121
# i=25200, t=122
# i=25300, t=123
# i=25400, t=123
# i=25500, t=124
# i=25600, t=125
# i=25700, t=125
# i=25800, t=126
# i=25900, t=126
# i=26000, t=127
# i=26100, t=128
# i=26200, t=128
# i=26300, t=129
# i=26400, t=129
# i=26500, t=130
# i=26600, t=131
# i=26700, t=131
# i=26800, t=132
# i=26900, t=132
# i=27000, t=133
# i=27100, t=134
# i=27200, t=134
# i=27300, t=135
# i=27400, t=136
# i=27500, t=136
# i=27600, t=137
# i=27700, t=138
# i=27800, t=138
# i=27900, t=139
# i=28000, t=139
# i=28100, t=140
# i=28200, t=141
# i=28300, t=141
# i=28400, t=142
# i=28500, t=143
# i=28600, t=143
# i=28700, t=144
# i=28800, t=145
# i=28900, t=145
# i=29000, t=146
# i=29100, t=147
# i=29200, t=147
# i=29300, t=148
# i=29400, t=149
# i=29500, t=149
# i=29600, t=150
# i=29700, t=150
# i=29800, t=151
# i=29900, t=152
# i=30000, t=152
# i=30100, t=153
# i=30200, t=154
# i=30300, t=154
# i=30400, t=155
# i=30500, t=156
# i=30600, t=156
# i=30700, t=157
# i=30800, t=158
# i=30900, t=158
# i=31000, t=159
# i=31100, t=160
# i=31200, t=160
# i=31300, t=161
# i=31400, t=162
# i=31500, t=162
# i=31600, t=163
# i=31700, t=164
# i=31800, t=164
# i=31900, t=165
# i=32000, t=166
# i=32100, t=167
# i=32200, t=167
# i=32300, t=168
# i=32400, t=169
# i=32500, t=169
# i=32600, t=170
# i=32700, t=171
# i=32800, t=171
# i=32900, t=172
# i=33000, t=173
# i=33100, t=173
# i=33200, t=174
# i=33300, t=175
# i=33400, t=175
# i=33500, t=176
# i=33600, t=177
# i=33700, t=177
# i=33800, t=178
# i=33900, t=179
# i=34000, t=179
# i=34100, t=180
# i=34200, t=181
# i=34300, t=182
# i=34400, t=182
# i=34500, t=183
# i=34600, t=184
# i=34700, t=184
# i=34800, t=185
# i=34900, t=186
# i=35000, t=186
# i=35100, t=187
# i=35200, t=188
# i=35300, t=188
# i=35400, t=189
# i=35500, t=190
# i=35600, t=191
# i=35700, t=191
# i=35800, t=192
# i=35900, t=193
# i=36000, t=193
# i=36100, t=194
# i=36200, t=195
# i=36300, t=196
# i=36400, t=196
# i=36500, t=197
# i=36600, t=198
# i=36700, t=198
# i=36800, t=199
# i=36900, t=200
# i=37000, t=200
# i=37100, t=201
# i=37200, t=202
# i=37300, t=203
# i=37400, t=203
# i=37500, t=204
# i=37600, t=205
# i=37700, t=206
# i=37800, t=206
# i=37900, t=207
# i=38000, t=208
# i=38100, t=208
# i=38200, t=209
# i=38300, t=210
# i=38400, t=211
# i=38500, t=211
# i=38600, t=212
# i=38700, t=213
# i=38800, t=213
# i=38900, t=214
# i=39000, t=215
# i=39100, t=216
# i=39200, t=216
# i=39300, t=217
# i=39400, t=218
# i=39500, t=219
# i=39600, t=219
# i=39700, t=220
# i=39800, t=221
# i=39900, t=222
# i=40000, t=222
# i=40100, t=223
# i=40200, t=224
# i=40300, t=225
# i=40400, t=225
# i=40500, t=226
# i=40600, t=227
# i=40700, t=227
# i=40800, t=228
# i=40900, t=229
# i=41000, t=230
# i=41100, t=230
# i=41200, t=231
# i=41300, t=232
# i=41400, t=233
# i=41500, t=233
# i=41600, t=234
# i=41700, t=235
# i=41800, t=236
# i=41900, t=236
# i=42000, t=237
# i=42100, t=238
# i=42200, t=239
# i=42300, t=240
# i=42400, t=240
# i=42500, t=241
# i=42600, t=242
# i=42700, t=243
# i=42800, t=243
# i=42900, t=244
# i=43000, t=245
# i=43100, t=246
# i=43200, t=246
# i=43300, t=247
# i=43400, t=248
# i=43500, t=249
# i=43600, t=249
# i=43700, t=250
# i=43800, t=251
# i=43900, t=252
# i=44000, t=253
# i=44100, t=253
# i=44200, t=254
# i=44300, t=255
# i=44400, t=256
# i=44500, t=256
# i=44600, t=257
# i=44700, t=258
# i=44800, t=259
# i=44900, t=260
# i=45000, t=260
# i=45100, t=261
# i=45200, t=262
# i=45300, t=263
# i=45400, t=263
# i=45500, t=264
# i=45600, t=265
# i=45700, t=266
# i=45800, t=267
# i=45900, t=267
# i=46000, t=268
# i=46100, t=269
# i=46200, t=270
# i=46300, t=271
# i=46400, t=271
# i=46500, t=272
# i=46600, t=273
# i=46700, t=274
# i=46800, t=274
# i=46900, t=275
# i=47000, t=276
# i=47100, t=277
# i=47200, t=278
# i=47300, t=278
# i=47400, t=279
# i=47500, t=280
# i=47600, t=281
# i=47700, t=282
# i=47800, t=283
# i=47900, t=283
# i=48000, t=284
# i=48100, t=285
# i=48200, t=286
# i=48300, t=287
# i=48400, t=287
# i=48500, t=288
# i=48600, t=289
# i=48700, t=290
# i=48800, t=291
# i=48900, t=291
# i=49000, t=292
# i=49100, t=293
# i=49200, t=294
# i=49300, t=295
# i=49400, t=296
# i=49500, t=296
# i=49600, t=297
# i=49700, t=298
# i=49800, t=299
# i=49900, t=300
# i=50000, t=300
# i=50100, t=301
# i=50200, t=302
# i=50300, t=303
# i=50400, t=304
# i=50500, t=305
# i=50600, t=305
# i=50700, t=306
# i=50800, t=307
# i=50900, t=308
# i=51000, t=309
# i=51100, t=310
# i=51200, t=310
# i=51300, t=311
# i=51400, t=312
# i=51500, t=313
# i=51600, t=314
# i=51700, t=315
# i=51800, t=315
# i=51900, t=316
# i=52000, t=317
# i=52100, t=318
# i=52200, t=319
# i=52300, t=320
# i=52400, t=321
# i=52500, t=321
# i=52600, t=322
# i=52700, t=323
# i=52800, t=324
# i=52900, t=325
# i=53000, t=326
# i=53100, t=327
# i=53200, t=328
# i=53300, t=328
# i=53400, t=329
# i=53500, t=330
# i=53600, t=331
# i=53700, t=332
# i=53800, t=333
# i=53900, t=334
# i=54000, t=335
# i=54100, t=335
# i=54200, t=336
# i=54300, t=337
# i=54400, t=338
# i=54500, t=339
# i=54600, t=340
# i=54700, t=341
# i=54800, t=341
# i=54900, t=342
# i=55000, t=343
# i=55100, t=344
# i=55200, t=345
# i=55300, t=346
# i=55400, t=347
# i=55500, t=348
# i=55600, t=348
# i=55700, t=349
# i=55800, t=350
# i=55900, t=351
# i=56000, t=352
# i=56100, t=353
# i=56200, t=354
# i=56300, t=355
# i=56400, t=356
# i=56500, t=356
# i=56600, t=357
# i=56700, t=358
# i=56800, t=359
# i=56900, t=360
# i=57000, t=361
# i=57100, t=362
# i=57200, t=363
# i=57300, t=364
# i=57400, t=364
# i=57500, t=365
# i=57600, t=366
# i=57700, t=367
# i=57800, t=368
# i=57900, t=369
# i=58000, t=370
# i=58100, t=371
# i=58200, t=372
# i=58300, t=373
# i=58400, t=373
# i=58500, t=374
# i=58600, t=375
# i=58700, t=376
# i=58800, t=377
# i=58900, t=378

# %%
K = 6;
fn_kmer = '/cndd/emukamel/snmCSeq/DMR/Kmer_Features/Kmers_K'+str(K)+'_counts.csv'
kmers = sparse.load_npz(fn_kmer.replace('.csv','.npz'))
# kmers = sparse.coo_matrix(kmers)

# %%
# if not torch.is_tensor(kmers):
#     values = kmers.data
#     indices = np.vstack((kmers.row, kmers.col))

#     i = torch.LongTensor(indices)
#     v = torch.FloatTensor(values)
#     shape = kmers.shape

#     kmers = torch.sparse.FloatTensor(i, v, torch.Size(shape))
def sparse2torch(kmers):
    kmers = sparse.coo_matrix(kmers)
    values = kmers.data
    indices = np.vstack((kmers.row, kmers.col))

    i = torch.LongTensor(indices)
    v = torch.FloatTensor(values)
    shape = kmers.shape

    return torch.sparse.FloatTensor(i, v, torch.Size(shape))

# %%
# Define the neural net architecture
n1 = 128;

# Define a class for the NN architecture
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear( nkmers, n1)
        self.fc3 = nn.Linear( n1, ncelltypes)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.fc3(x)
        return x

net = Net()

# %%
net = Net()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
if device is not "cpu":
    net.to(torch.device(device))
# criterion = nn.MSELoss()
# penalty = nn.L1Loss()
mseloss=nn.MSELoss()

lr = 0.01
optimizer = optim.SGD(net.parameters(), lr=lr, momentum=0.9)
# optimizer = optim.Adam(net.parameters(), lr=lr)

batch_size=20
if device is not "cpu":
    net.to(device)
net.train
running_time = 0
loss_vec = corr_vec = []
nepochs = 0
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer)

# %%
out_fn='KmerRegression_K%d_TorchTrained_%s.lr%3.3f.save' % (K, datetime.datetime.now().strftime('%m-%d-%y'),lr)
print(out_fn)

loss_test=np.array([])
loss_train = np.array([])
nparams = np.array([])
l1params = np.array([])
# Out:
# KmerRegression_K8_TorchTrained_11-29-19.lr0.010.save

# %%
# out_fn='CNN_trained_11-19-19.seqsize600.lr0.010.save'
# checkpoint = torch.load(out_fn)
# print(checkpoint.keys())
# net.load_state_dict(checkpoint['net_state'])
# loss_train = np.array(checkpoint['loss_train'])
# loss_test = np.array(checkpoint['loss_test'])
# len(loss_test)

# %%
dmrs_mc_mean = torch.mean(dmrs_mc, dim=1).reshape([-1,1])
# dmrs_mcu = dmrs_mc - dmrs_mc_mean
dmrs_mcu = dmrs_mc 
dmrs_mc_mean.shape
# Out:
# torch.Size([58959, 1])

# %%
l1_alpha = 0.01/nkmers;

lr = 0.001
optimizer = optim.SGD(net.parameters(), lr=lr, momentum=0.9)

def criterion(y,yhat,weights):
    loss = nn.MSELoss()(y,yhat) + l1_alpha*torch.norm(weights,1)
    return loss

def Numparams(weights):
    l1 = torch.sum(torch.abs(weights))
    nparms = torch.sum(torch.abs(weights)>0)
    
    return nparms.cpu().detach(), l1.cpu().detach()

# X = torch.transpose(seqs_1hot_tensor.float(),2,1).float()
trainfrac = 0.8
num_epochs = 100
batch_size=64

torch.manual_seed(0)
permutation = torch.randperm(ndmrs)
ntrain = round(ndmrs*trainfrac)

training = permutation[:ntrain]
testing = permutation[ntrain:(ntrain+1000)]

# %%
for epoch in range(num_epochs):  # loop over the dataset multiple times
    running_time = 0

    np_curr, l1 = Numparams(net.fc1.weight)
    nparams = np.append(nparams,np_curr)
    l1params = np.append(l1params,l1)
    
    start=time.time()
    nsamp=0
    running_loss = 0.0
    net.train()
    for i in range(0, len(training), batch_size):
        indices = training[i:i+batch_size]

        # Input should be of size: (batch, channels, samples)
        batch_X = sparse2torch(kmers[indices,:]).float()
#         batch_X = torch.transpose(batch_X.float(),2,1).float()
        batch_dmrs_mc = dmrs_mcu[indices]

        # Send training data to CUDA
        if device is not "cpu":
            batch_X = batch_X.to(device)
            batch_dmrs_mc = batch_dmrs_mc.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(batch_X)
        loss = criterion(outputs, batch_dmrs_mc, net.fc1.weight)
        loss.backward()
        optimizer.step()

#         print('Train: i=%d, loss=%g' % (i, loss.item()))
        running_loss += mseloss(outputs, batch_dmrs_mc).item()
        nsamp += 1
        if (time.time()-start)>5:
            # print statistics
            running_time += time.time()-start
            print('  [Batch size %d, Epoch %d, Item %d/%d, %3.1f%% of data] loss: %.3g; %3.3fs per 1000 items' %
                  (batch_size, len(loss_test), i, len(training), 100*i/len(training), running_loss/nsamp, 1000*running_time/i))
            start = time.time()
    loss_train = np.append(loss_train,running_loss/nsamp)
            
    # Test/Validate
    net.eval()
    running_loss_test = 0.0
    nsamp = 0
    for i in range(0, len(testing), batch_size):
        indices = testing[i:i+batch_size]

        # Input should be of size: (batch, channels, samples)
        batch_X = sparse2torch(kmers[indices,:]).float()
#         batch_X = torch.transpose(batch_X.float(),2,1).float()
        batch_dmrs_mc = dmrs_mcu[indices]

        # Send training data to CUDA
        if device is not "cpu":
            batch_X = batch_X.to(device)
            batch_dmrs_mc = batch_dmrs_mc.to(device)

        # forward + backward + optimize
        outputs = net(batch_X)
#         loss = criterion(outputs, batch_dmrs_mc, net.parameters()) 

        running_loss_test += mseloss(outputs, batch_dmrs_mc).item()
        nsamp += 1
    loss_test = np.append(loss_test,running_loss_test/nsamp)

    print('*** Epoch %d/%d, %d total training epochs, loss for train: %3.6g, test: %3.6g, time=%3.3f s' %
          (len(loss_test), num_epochs, len(loss_train), loss_train[-1], loss_test[-1], running_time))

    torch.save({
        'net_state': net.state_dict(),
        'loss_train': loss_train,
        'loss_test': loss_test,
    }, out_fn)
    print('Saved %s' % out_fn)
    
    scheduler.step(running_loss_test/nsamp)
    
    ##
    if len(loss_train)>1:
        clear_output()
        plt.figure(figsize=(15,4))
        plt.subplot(1,2,1)
        plt.plot(loss_train/loss_train[0],'s-')
        plt.plot(loss_test/loss_test[0],'o-')
        plt.legend(['Train','Test'])
        plt.title('%s\n%d training iterations\nMin test loss=%3.3g, Learn rate=%3.3g, np=%3.3g, l1=%3.3g' % 
                  (out_fn, len(loss_train), np.min(loss_test/loss_test[0]), optimizer.param_groups[0]['lr'],
                  np_curr, l1))
        plt.grid()
        plt.xlabel('Epoch')
        plt.ylabel('MSE')
        # plt.xlim([0,80]);
        
        plt.subplot(2,2,2)
        plt.plot(l1params)
        plt.ylabel('L1 norm of parameters')
        plt.subplot(2,2,4)
        plt.plot(nparams)
        plt.ylabel('Number of parameters')
        
        plt.show()
print('Finished Training')
# Out:
#   [Batch size 64, Epoch 0, Item 256/47167, 0.5% of data] loss: 0.0955; 20.595s per 1000 items
#   [Batch size 64, Epoch 0, Item 576/47167, 1.2% of data] loss: 0.0907; 18.258s per 1000 items
#   [Batch size 64, Epoch 0, Item 896/47167, 1.9% of data] loss: 0.0879; 17.752s per 1000 items
#   [Batch size 64, Epoch 0, Item 1216/47167, 2.6% of data] loss: 0.0883; 17.360s per 1000 items
#   [Batch size 64, Epoch 0, Item 1536/47167, 3.3% of data] loss: 0.0905; 17.217s per 1000 items
#   [Batch size 64, Epoch 0, Item 1856/47167, 3.9% of data] loss: 0.0926; 17.079s per 1000 items
#   [Batch size 64, Epoch 0, Item 2176/47167, 4.6% of data] loss: 0.0947; 17.040s per 1000 items
#   [Batch size 64, Epoch 0, Item 2496/47167, 5.3% of data] loss: 0.0964; 16.974s per 1000 items
#   [Batch size 64, Epoch 0, Item 2816/47167, 6.0% of data] loss: 0.0977; 17.022s per 1000 items
#   [Batch size 64, Epoch 0, Item 3136/47167, 6.6% of data] loss: 0.0991; 16.953s per 1000 items
#   [Batch size 64, Epoch 0, Item 3456/47167, 7.3% of data] loss: 0.0993; 16.942s per 1000 items
#   [Batch size 64, Epoch 0, Item 3776/47167, 8.0% of data] loss: 0.0995; 16.936s per 1000 items
#   [Batch size 64, Epoch 0, Item 4096/47167, 8.7% of data] loss: 0.101; 16.907s per 1000 items
#   [Batch size 64, Epoch 0, Item 4416/47167, 9.4% of data] loss: 0.101; 16.918s per 1000 items
#   [Batch size 64, Epoch 0, Item 4736/47167, 10.0% of data] loss: 0.101; 16.881s per 1000 items
#   [Batch size 64, Epoch 0, Item 5056/47167, 10.7% of data] loss: 0.102; 16.843s per 1000 items
#   [Batch size 64, Epoch 0, Item 5376/47167, 11.4% of data] loss: 0.102; 16.841s per 1000 items
#   [Batch size 64, Epoch 0, Item 5696/47167, 12.1% of data] loss: 0.102; 16.834s per 1000 items
#   [Batch size 64, Epoch 0, Item 6016/47167, 12.8% of data] loss: 0.102; 16.850s per 1000 items
#   [Batch size 64, Epoch 0, Item 6336/47167, 13.4% of data] loss: 0.103; 16.858s per 1000 items
#   [Batch size 64, Epoch 0, Item 6656/47167, 14.1% of data] loss: 0.103; 16.827s per 1000 items
#   [Batch size 64, Epoch 0, Item 6976/47167, 14.8% of data] loss: 0.103; 16.843s per 1000 items
#   [Batch size 64, Epoch 0, Item 7296/47167, 15.5% of data] loss: 0.103; 16.834s per 1000 items
#   [Batch size 64, Epoch 0, Item 7616/47167, 16.1% of data] loss: 0.103; 16.845s per 1000 items
#   [Batch size 64, Epoch 0, Item 7936/47167, 16.8% of data] loss: 0.103; 16.836s per 1000 items
#   [Batch size 64, Epoch 0, Item 8256/47167, 17.5% of data] loss: 0.103; 16.843s per 1000 items
#   [Batch size 64, Epoch 0, Item 8576/47167, 18.2% of data] loss: 0.103; 16.851s per 1000 items
#   [Batch size 64, Epoch 0, Item 8896/47167, 18.9% of data] loss: 0.103; 16.838s per 1000 items
#   [Batch size 64, Epoch 0, Item 9216/47167, 19.5% of data] loss: 0.103; 16.841s per 1000 items
#   [Batch size 64, Epoch 0, Item 9536/47167, 20.2% of data] loss: 0.103; 16.845s per 1000 items
#   [Batch size 64, Epoch 0, Item 9856/47167, 20.9% of data] loss: 0.104; 16.839s per 1000 items
#   [Batch size 64, Epoch 0, Item 10176/47167, 21.6% of data] loss: 0.104; 16.864s per 1000 items
#   [Batch size 64, Epoch 0, Item 10496/47167, 22.3% of data] loss: 0.104; 16.847s per 1000 items
#   [Batch size 64, Epoch 0, Item 10816/47167, 22.9% of data] loss: 0.104; 16.855s per 1000 items
#   [Batch size 64, Epoch 0, Item 11136/47167, 23.6% of data] loss: 0.104; 16.846s per 1000 items
#   [Batch size 64, Epoch 0, Item 11456/47167, 24.3% of data] loss: 0.104; 16.840s per 1000 items
#   [Batch size 64, Epoch 0, Item 11776/47167, 25.0% of data] loss: 0.104; 16.843s per 1000 items
#   [Batch size 64, Epoch 0, Item 12096/47167, 25.6% of data] loss: 0.104; 16.825s per 1000 items
#   [Batch size 64, Epoch 0, Item 12416/47167, 26.3% of data] loss: 0.104; 16.824s per 1000 items
#   [Batch size 64, Epoch 0, Item 12736/47167, 27.0% of data] loss: 0.104; 16.817s per 1000 items
#   [Batch size 64, Epoch 0, Item 13056/47167, 27.7% of data] loss: 0.104; 16.811s per 1000 items
#   [Batch size 64, Epoch 0, Item 13376/47167, 28.4% of data] loss: 0.104; 16.803s per 1000 items
#   [Batch size 64, Epoch 0, Item 13696/47167, 29.0% of data] loss: 0.104; 16.818s per 1000 items
#   [Batch size 64, Epoch 0, Item 14016/47167, 29.7% of data] loss: 0.104; 16.816s per 1000 items
#   [Batch size 64, Epoch 0, Item 14336/47167, 30.4% of data] loss: 0.104; 16.810s per 1000 items
#   [Batch size 64, Epoch 0, Item 14656/47167, 31.1% of data] loss: 0.104; 16.803s per 1000 items
#   [Batch size 64, Epoch 0, Item 14976/47167, 31.8% of data] loss: 0.104; 16.804s per 1000 items
#   [Batch size 64, Epoch 0, Item 15296/47167, 32.4% of data] loss: 0.104; 16.799s per 1000 items
#   [Batch size 64, Epoch 0, Item 15616/47167, 33.1% of data] loss: 0.104; 16.799s per 1000 items
#   [Batch size 64, Epoch 0, Item 15936/47167, 33.8% of data] loss: 0.104; 16.798s per 1000 items
#   [Batch size 64, Epoch 0, Item 16256/47167, 34.5% of data] loss: 0.104; 16.798s per 1000 items
#   [Batch size 64, Epoch 0, Item 16576/47167, 35.1% of data] loss: 0.104; 16.802s per 1000 items
#   [Batch size 64, Epoch 0, Item 16896/47167, 35.8% of data] loss: 0.104; 16.790s per 1000 items
#   [Batch size 64, Epoch 0, Item 17216/47167, 36.5% of data] loss: 0.104; 16.798s per 1000 items
#   [Batch size 64, Epoch 0, Item 17536/47167, 37.2% of data] loss: 0.105; 16.797s per 1000 items
#   [Batch size 64, Epoch 0, Item 17856/47167, 37.9% of data] loss: 0.105; 16.793s per 1000 items
#   [Batch size 64, Epoch 0, Item 18176/47167, 38.5% of data] loss: 0.105; 16.798s per 1000 items
#   [Batch size 64, Epoch 0, Item 18496/47167, 39.2% of data] loss: 0.105; 16.802s per 1000 items
#   [Batch size 64, Epoch 0, Item 18816/47167, 39.9% of data] loss: 0.105; 16.793s per 1000 items
#   [Batch size 64, Epoch 0, Item 19136/47167, 40.6% of data] loss: 0.105; 16.794s per 1000 items
#   [Batch size 64, Epoch 0, Item 19456/47167, 41.2% of data] loss: 0.105; 16.788s per 1000 items
#   [Batch size 64, Epoch 0, Item 19776/47167, 41.9% of data] loss: 0.105; 16.785s per 1000 items
#   [Batch size 64, Epoch 0, Item 20096/47167, 42.6% of data] loss: 0.105; 16.789s per 1000 items
#   [Batch size 64, Epoch 0, Item 20416/47167, 43.3% of data] loss: 0.105; 16.789s per 1000 items
#   [Batch size 64, Epoch 0, Item 20736/47167, 44.0% of data] loss: 0.104; 16.783s per 1000 items
#   [Batch size 64, Epoch 0, Item 21056/47167, 44.6% of data] loss: 0.105; 16.786s per 1000 items
#   [Batch size 64, Epoch 0, Item 21376/47167, 45.3% of data] loss: 0.105; 16.786s per 1000 items
#   [Batch size 64, Epoch 0, Item 21696/47167, 46.0% of data] loss: 0.105; 16.790s per 1000 items
#   [Batch size 64, Epoch 0, Item 22016/47167, 46.7% of data] loss: 0.105; 16.790s per 1000 items
#   [Batch size 64, Epoch 0, Item 22336/47167, 47.4% of data] loss: 0.105; 16.786s per 1000 items
#   [Batch size 64, Epoch 0, Item 22656/47167, 48.0% of data] loss: 0.105; 16.784s per 1000 items
#   [Batch size 64, Epoch 0, Item 22976/47167, 48.7% of data] loss: 0.105; 16.782s per 1000 items
#   [Batch size 64, Epoch 0, Item 23296/47167, 49.4% of data] loss: 0.105; 16.783s per 1000 items
#   [Batch size 64, Epoch 0, Item 23616/47167, 50.1% of data] loss: 0.105; 16.780s per 1000 items
#   [Batch size 64, Epoch 0, Item 23936/47167, 50.7% of data] loss: 0.105; 16.776s per 1000 items
#   [Batch size 64, Epoch 0, Item 24256/47167, 51.4% of data] loss: 0.105; 16.775s per 1000 items
#   [Batch size 64, Epoch 0, Item 24576/47167, 52.1% of data] loss: 0.105; 16.779s per 1000 items
#   [Batch size 64, Epoch 0, Item 24896/47167, 52.8% of data] loss: 0.105; 16.772s per 1000 items
#   [Batch size 64, Epoch 0, Item 25216/47167, 53.5% of data] loss: 0.105; 16.764s per 1000 items
#   [Batch size 64, Epoch 0, Item 25536/47167, 54.1% of data] loss: 0.105; 16.767s per 1000 items
#   [Batch size 64, Epoch 0, Item 25856/47167, 54.8% of data] loss: 0.104; 16.763s per 1000 items
#   [Batch size 64, Epoch 0, Item 26176/47167, 55.5% of data] loss: 0.105; 16.763s per 1000 items
#   [Batch size 64, Epoch 0, Item 26496/47167, 56.2% of data] loss: 0.104; 16.763s per 1000 items
#   [Batch size 64, Epoch 0, Item 26816/47167, 56.9% of data] loss: 0.104; 16.764s per 1000 items
#   [Batch size 64, Epoch 0, Item 27136/47167, 57.5% of data] loss: 0.104; 16.762s per 1000 items
#   [Batch size 64, Epoch 0, Item 27456/47167, 58.2% of data] loss: 0.104; 16.756s per 1000 items
#   [Batch size 64, Epoch 0, Item 27776/47167, 58.9% of data] loss: 0.104; 16.756s per 1000 items

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(loss_train/loss_train[0],'s-')
plt.plot(loss_test/loss_test[0],'o-')
plt.legend(['Train','Test'])
# plt.title('%s\n%d training iterations\nMin test loss=%3.3g, Learn rate=%3.3g, np=%3.3g, l1=%3.3g' % 
#           (out_fn, len(loss_train), np.min(loss_test/loss_test[0]), optimizer.param_groups[0]['lr'],
#           np_curr, l1))
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('Loss')
# plt.xlim([0,80]);

plt.subplot(2,2,2)
plt.plot(l1params)
plt.ylabel('L1 norm of parameters')
plt.subplot(2,2,4)
plt.plot(nparams)
plt.ylabel('Number of parameters')
# Out:
# Text(0, 0.5, 'Number of parameters')

# %%
# Test/Validate
net.eval()
dmrs_mc_hat = np.zeros(dmrs_mc.shape)
for i in range(0, len(testing), batch_size):
    indices = testing[i:i+batch_size]

    # Input should be of size: (batch, channels, samples)
#     batch_X = kmers[indices,:].float()
    batch_X = sparse2torch(kmers[indices,:]).float()
#     batch_X = torch.transpose(batch_X.float(),2,1).float()
    batch_dmrs_mc = dmrs_mcu[indices]

    # Send training data to CUDA
    if device is not "cpu":
        batch_X = batch_X.to(device)
        batch_dmrs_mc = batch_dmrs_mc.to(device)

    # forward + backward + optimize
    outputs = net(batch_X)
    dmrs_mc_hat[indices,:] = outputs.cpu().detach().numpy()

# %%
y = dmrs_mc[testing,:]-dmrs_mc_mean[testing]
yhat = dmrs_mc_hat[testing,:]-dmrs_mc_mean[testing].numpy()
plt.plot(y, yhat, '.');

# %%
r = [np.corrcoef(y[:,i],yhat[:,i])[0,1] for i in range(ncelltypes)]
r_spearman = [spearmanr(y[:,i],yhat[:,i]).correlation for i in range(ncelltypes)]
R2 = [1-r**2 for r in r]
# plt.plot(R2)
# plt.plot(plt.xlim(),[np.mean(R2)]*2,'k--')
plt.plot(r_spearman)
plt.plot(r)
plt.plot(plt.xlim(),[np.mean(r)]*2,'k--')
plt.xlabel('Cell type')
plt.ylabel('Correlation of DMR mCG with prediction')
print('r = %3.3f (%3.3f-%3.3f)' % (np.mean(r), np.min(r), np.max(r)))
# Out:
# r = 0.270 (0.072-0.524)

# %%
# Visualize the weight matrices
weights = net.state_dict()['conv1.weight'].cpu().numpy()
plt.figure(figsize=(ncelltypes,2*nfilt/4))
for jfeature in range(weights.shape[0]):
    plt.subplot(nfilt/4,4,jfeature+1,xmargin=-0.4)
    weight = weights[jfeature,:,:].squeeze()
#     plt.imshow(weight, aspect='auto', vmin=-.1,vmax=.1)
    plt.imshow(weight, aspect='auto')
    plt.xticks([])
    if (jfeature % 4 ==0):
        plt.yticks(list(acgt_to_int.values()),list(acgt_to_int.keys()))
    else:
        plt.yticks([])
#     if jfeature>5:
#         break

plt.subplots_adjust(wspace=0.05)
plt.colorbar();
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-297a8e21d9e5> in <module>
#       3 plt.figure(figsize=(ncelltypes,2*nfilt/4))
#       4 for jfeature in range(weights.shape[0]):
# ----> 5     plt.subplot(nfilt/4,4,jfeature+1,xmargin=-0.4)
#       6     weight = weights[jfeature,:,:].squeeze()
#       7 #     plt.imshow(weight, aspect='auto', vmin=-.1,vmax=.1)
#
# /cndd/emukamel/conda_envs/cembadata_eran/lib/python3.6/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1068
#    1069     fig = gcf()
# -> 1070     a = fig.add_subplot(*args, **kwargs)
#    1071     bbox = a.bbox
#    1072     byebye = []
#
# /cndd/emukamel/conda_envs/cembadata_eran/lib/python3.6/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
#    1416         return self._add_axes_internal(key, a)
#
# /cndd/emukamel/conda_envs/cembadata_eran/lib/python3.6/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      57                 if num < 1 or num > rows*cols:
#      58                     raise ValueError(
# ---> 59                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      60                 self._subplotspec = GridSpec(
#      61                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 8, not 9
